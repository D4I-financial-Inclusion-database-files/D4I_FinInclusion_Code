# %% [markdown]
# # COVID 19 Tracking File
# #### Date Created: 11/19
# #### Main Author:

# %% [markdown]
# #### Quick Summary:
#
# <li> </li>

# %% [markdown]
# ## To Do List
# <li>  </li>

# %% [markdown]
# ## Imports:

# %%
import requests

url = 'https://localcoviddata.com/covid19/v1/cases/eucdc?country=ES&daysInPast=1'
req = requests.get(url)

print(req.status_code)
print(req.headers)
print(req.text)
# Out:
# 500
# {'Content-Type': 'application/json; charset=UTF-8', 'Content-Length': '48', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains;', 'Expires': 'Fri, 19 Nov 2021 19:53:26 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Fri, 19 Nov 2021 19:53:26 GMT', 'Connection': 'keep-alive'}
# {
#   "message": "There was a processing error."
# }

# %%
url = "https://api.covid19api.com/live/country/south-africa/status/confirmed/date/2020-03-21T13:13:30Z"

payload={}
headers = {}

response = requests.get("https://api.covid19api.com/live/country/south-africa/status/confirmed/date/2020-03-21T13:13:30Z")

response.json()
# Out:
# [{'ID': '2fb4b60d-efcd-47c3-b4d9-44c58328cdd0',
#   'Country': 'South Africa',
#   'CountryCode': 'ZA',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '-30.56',
#   'Lon': '22.94',
#   'Confirmed': 1877143,
#   'Deaths': 59406,
#   'Recovered': 1675827,
#   'Active': 141910,
#   'Date': '2021-06-25T00:00:00Z'},
#  {'ID': 'd2970361-321a-4491-a19d-825121a91cb3',
#   'Country': 'South Africa',
#   'CountryCode': 'ZA',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '-30.56',
#   'Lon': '22.94',
#   'Confirmed': 1895905,
#   'Deaths': 59621,
#   'Recovered': 1690380,
#   'Active': 145904,
#   'Date': '2021-06-26T00:00:00Z'},
#  {'ID': 'ba4eb46d-b2c3-4e00-ac00-e3ab029c2779',
#   'Country': 'South Africa',
#   'CountryCode': 'ZA',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '-30.56',
#   'Lon': '22.94',
#   'Confirmed': 1913861,
#   'Deaths': 59778,
#   'Recovered': 1702070,
#   'Active': 152013,
# ...

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# ## Input the Data:

# %%
##Code

# %% [markdown]
# ## Data Manipulation:

# %%
## Code

# %% [markdown]
# ## Functions:

# %%
## Code
