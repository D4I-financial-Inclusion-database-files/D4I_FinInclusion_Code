# %% [markdown]
# ### merging datasets version 1
#
# <p>
#     sorry this is late, v1 by rishi, im gonna try to go step by step, later im gonna outline what we need to do remaining
# </p>

# %%
import numpy as np
import pandas as pd
import datetime

# %%
#Datasets with one variable to start out
#UV rays (from 2004?)
uv_who = pd.read_csv('https://raw.githubusercontent.com/D4I-financial-Inclusion-database-files/D4I_FinInclusion_Data/4f02f5180288d04e74897b4574aec2dbea53ec15/BMJ_Data/uv%20WHO%20data.csv')

# BCG immunization rates
bcg_who = pd.read_csv('https://raw.githubusercontent.com/D4I-financial-Inclusion-database-files/D4I_FinInclusion_Data/main/BMJ_Data_Country_Article/BCGWHOdata.csv')

#Russian Rainfall 
#NEEDS SOURCE
rus_rain = pd.read_csv('https://raw.githubusercontent.com/D4I-financial-Inclusion-database-files/D4I_FinInclusion_Data/main/BMJ_Data_Country_Article/rainfall_1991_2020_RUS.csv')

#Russian Temp
#NEEDS SOURCE
rus_temp = pd.read_csv('https://raw.githubusercontent.com/D4I-financial-Inclusion-database-files/D4I_FinInclusion_Data/main/BMJ_Data_Country_Article/Temp_1991_2020_RUS.csv')

#Diabetes Prevelance (World Bank)
diabetes_wb = pd.read_csv('https://raw.githubusercontent.com/D4I-financial-Inclusion-database-files/D4I_FinInclusion_Data/main/BMJ_Data_Country_Article/worldbankdiabetesprevelance.csv')

# %%
country_codes = pd.read_csv('https://raw.githubusercontent.com/D4I-financial-Inclusion-database-files/D4I_FinInclusion_Data/main/countries_codes_and_coordinates.csv')
country_codes.describe()
# Out:
#                  Country Alpha-2 code Alpha-3 code Numeric code  \
# count                256          256          256          256
# unique               256          244          244          244
# top     Papua New Guinea         "VC"        "VCT"        "670"
# freq                   1            3            3            3
#
#        Latitude (average) Longitude (average)
# count                 256                 256
# unique                176                 196
# top                   "8"                "30"
# freq                    8                   7

# %% [markdown]
# ### Editing UV WHO dataset
#
# note: 191 countries

# %%
uv_who.head()
# Out:
#     Unnamed: 0  UV radiation
# 0      Country          2004
# 1  Afghanistan          4132
# 2      Albania          2542
# 3      Algeria          3253
# 4      Andorra          2469

# %% [markdown]
# - we need to :
#     - delete the first row
#     - rename the first column

# %%
uv_who.columns = ["Country", "UV"]
# Ideally we would see what units its measured in and include that in column name

uv_who = uv_who.drop(0)
uv_who.head()
# Out:
#        Country    UV
# 1  Afghanistan  4132
# 2      Albania  2542
# 3      Algeria  3253
# 4      Andorra  2469
# 5       Angola  5287

# %%
uv_who.describe()
uv = uv_who
# Out:
#                  UV
# count    191.000000
# mean    4075.753927
# std     1451.755858
# min      957.000000
# 25%     2744.500000
# 50%     4555.000000
# 75%     5180.000000
# max    10224.000000

# %% [markdown]
# - we have 191 countries in the UV dataset

# %% [markdown]
# ### Editing BCG WHO Data
# note: 156 countries

# %%
bcg_who.head()
# Out:
#     Unnamed: 0  BCG immunization coverage among 1-year-olds (%)  \
# 0      Country                                           2019.0
# 1  Afghanistan                                             78.0
# 2      Albania                                             99.0
# 3      Algeria                                             99.0
# 4       Angola                                             69.0
#
#    BCG immunization coverage among 1-year-olds (%).1  \
# 0                                             2018.0
# 1                                               78.0
# 2                                               99.0
# 3                                               99.0
# 4                                               72.0
#
#    BCG immunization coverage among 1-year-olds (%).2  \
# 0                                             2017.0
# 1                                               78.0
# 2                                               99.0
# 3                                               99.0
# 4                                               69.0
#
#    BCG immunization coverage among 1-year-olds (%).3  \
# 0                                             2016.0
# 1                                               78.0
# 2                                               99.0
# 3                                               99.0
# 4                                               40.0
#
#    BCG immunization coverage among 1-year-olds (%).4  \
# 0                                             2015.0
# 1                                               76.0
# 2                                               99.0
# 3                                               99.0
# 4                                               64.0
#
#    BCG immunization coverage among 1-year-olds (%).5  \
# 0                                             2014.0
# 1                                               74.0
# 2                                               99.0
# 3                                               99.0
# 4                                               72.0
#
#    BCG immunization coverage among 1-year-olds (%).6  \
# 0                                             2013.0
# 1                                               72.0
# 2                                               99.0
# 3                                               99.0
# 4                                               71.0
#
#    BCG immunization coverage among 1-year-olds (%).7  \
# 0                                             2012.0
# 1                                               78.0
# 2                                               96.0
# 3                                               99.0
# 4                                               73.0
#
#    BCG immunization coverage among 1-year-olds (%).8  ...  \
# 0                                             2011.0  ...
# 1                                               71.0  ...
# 2                                               97.0  ...
# 3                                               99.0  ...
# 4                                               74.0  ...
#
#    BCG immunization coverage among 1-year-olds (%).30  \
# 0                                             1989.0
# 1                                               38.0
# 2                                               94.0
# 3                                               96.0
# 4                                               47.0
#
#    BCG immunization coverage among 1-year-olds (%).31  \
# 0                                             1988.0
# 1                                               40.0
# 2                                               92.0
# 3                                               96.0
# 4                                               32.0
#
#    BCG immunization coverage among 1-year-olds (%).32  \
# 0                                             1987.0
# 1                                               27.0
# 2                                               92.0
# 3                                               93.0
# 4                                               29.0
#
#    BCG immunization coverage among 1-year-olds (%).33  \
# 0                                             1986.0
# 1                                               18.0
# 2                                               92.0
# 3                                               88.0
# 4                                               32.0
#
#    BCG immunization coverage among 1-year-olds (%).34  \
# 0                                             1985.0
# 1                                               17.0
# 2                                               92.0
# 3                                               86.0
# 4                                               28.0
#
#    BCG immunization coverage among 1-year-olds (%).35  \
# 0                                             1984.0
# 1                                               11.0
# 2                                               90.0
# 3                                                NaN
# 4                                               28.0
#
#    BCG immunization coverage among 1-year-olds (%).36  \
# 0                                             1983.0
# 1                                               10.0
# 2                                               90.0
# 3                                                NaN
# 4                                               25.0
#
#    BCG immunization coverage among 1-year-olds (%).37  \
# 0                                             1982.0
# 1                                               10.0
# 2                                               92.0
# 3                                                NaN
# 4                                                NaN
#
#    BCG immunization coverage among 1-year-olds (%).38  \
# 0                                             1981.0
# 1                                                NaN
# 2                                               93.0
# 3                                                NaN
# 4                                                NaN
#
#    BCG immunization coverage among 1-year-olds (%).39
# 0                                             1980.0
# 1                                                NaN
# 2                                               93.0
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 41 columns]

# %%
bcg_who.describe()
# Out:
#        BCG immunization coverage among 1-year-olds (%)  \
# count                                       156.000000
# mean                                        102.314103
# std                                         154.919534
# min                                          25.000000
# 25%                                          86.000000
# 50%                                          95.000000
# 75%                                          98.000000
# max                                        2019.000000
#
#        BCG immunization coverage among 1-year-olds (%).1  \
# count                                         156.000000
# mean                                          102.923077
# std                                           154.780825
# min                                            26.000000
# 25%                                            89.000000
# 50%                                            95.000000
# 75%                                            98.000000
# max                                          2018.000000
#
#        BCG immunization coverage among 1-year-olds (%).2  \
# count                                         156.000000
# mean                                          103.410256
# std                                           154.615313
# min                                            25.000000
# 25%                                            89.000000
# 50%                                            95.000000
# 75%                                            98.000000
# max                                          2017.000000
#
#        BCG immunization coverage among 1-year-olds (%).3  \
# count                                         157.000000
# mean                                          102.853503
# std                                           154.228261
# min                                            18.000000
# 25%                                            89.000000
# 50%                                            96.000000
# 75%                                            98.000000
# max                                          2016.000000
#
#        BCG immunization coverage among 1-year-olds (%).4  \
# count                                         158.000000
# mean                                          102.386076
# std                                           153.734767
# min                                            24.000000
# 25%                                            87.250000
# 50%                                            96.000000
# 75%                                            99.000000
# max                                          2015.000000
#
#        BCG immunization coverage among 1-year-olds (%).5  \
# count                                         158.000000
# mean                                          103.265823
# std                                           153.479616
# min                                            26.000000
# 25%                                            89.250000
# 50%                                            96.000000
# 75%                                            99.000000
# max                                          2014.000000
#
#        BCG immunization coverage among 1-year-olds (%).6  \
# count                                         158.000000
# mean                                          103.424051
# std                                           153.401280
# min                                            27.000000
# 25%                                            90.250000
# 50%                                            96.000000
# 75%                                            99.000000
# max                                          2013.000000
#
#        BCG immunization coverage among 1-year-olds (%).7  \
# count                                         160.000000
# mean                                          104.031250
# std                                           152.227917
# min                                            24.000000
# 25%                                            90.750000
# 50%                                            96.000000
# 75%                                            99.000000
# max                                          2012.000000
#
#        BCG immunization coverage among 1-year-olds (%).8  \
# count                                         160.000000
# mean                                          103.443750
# std                                           152.252387
# min                                            23.000000
# 25%                                            90.000000
# 50%                                            97.000000
# 75%                                            99.000000
# max                                          2011.000000
#
#        BCG immunization coverage among 1-year-olds (%).9  ...  \
# count                                          159.00000  ...
# mean                                           103.63522  ...
# std                                            152.61731  ...
# min                                             23.00000  ...
# 25%                                             90.00000  ...
# 50%                                             96.00000  ...
# 75%                                             99.00000  ...
# max                                           2010.00000  ...
#
#        BCG immunization coverage among 1-year-olds (%).30  \
# count                                         135.000000
# mean                                           95.207407
# std                                           165.437236
# min                                             8.000000
# 25%                                            74.500000
# 50%                                            90.000000
# 75%                                            96.000000
# max                                          1989.000000
#
#        BCG immunization coverage among 1-year-olds (%).31  \
# count                                         134.000000
# mean                                           91.925373
# std                                           166.338708
# min                                            14.000000
# 25%                                            66.000000
# 50%                                            86.000000
# 75%                                            95.000000
# max                                          1988.000000
#
#        BCG immunization coverage among 1-year-olds (%).32  \
# count                                         132.000000
# mean                                           88.189394
# std                                           168.036216
# min                                            14.000000
# 25%                                            60.750000
# 50%                                            80.500000
# 75%                                            93.000000
# max                                          1987.000000
#
#        BCG immunization coverage among 1-year-olds (%).33  \
# count                                         132.000000
# mean                                           84.037879
# std                                           168.669576
# min                                             4.000000
# 25%                                            53.000000
# 50%                                            76.000000
# 75%                                            92.000000
# max                                          1986.000000
#
#        BCG immunization coverage among 1-year-olds (%).34  \
# count                                         130.000000
# mean                                           80.315385
# std                                           170.450931
# min                                             2.000000
# 25%                                            47.750000
# 50%                                            74.500000
# 75%                                            89.750000
# max                                          1985.000000
#
#        BCG immunization coverage among 1-year-olds (%).35  \
# count                                         125.000000
# mean                                           76.160000
# std                                           174.130068
# min                                             2.000000
# 25%                                            42.000000
# 50%                                            66.000000
# 75%                                            85.000000
# max                                          1984.000000
#
#        BCG immunization coverage among 1-year-olds (%).36  \
# count                                         117.000000
# mean                                           76.965812
# std                                           179.895752
# min                                             2.000000
# 25%                                            41.000000
# 50%                                            65.000000
# 75%                                            83.000000
# max                                          1983.000000
#
#        BCG immunization coverage among 1-year-olds (%).37  \
# count                                         111.000000
# mean                                           75.918919
# std                                           184.852970
# min                                             1.000000
# 25%                                            37.500000
# 50%                                            62.000000
# 75%                                            83.500000
# max                                          1982.000000
#
#        BCG immunization coverage among 1-year-olds (%).38  \
# count                                         105.000000
# mean                                           74.076190
# std                                           190.160949
# min                                             1.000000
# 25%                                            32.000000
# 50%                                            59.000000
# 75%                                            81.000000
# max                                          1981.000000
#
#        BCG immunization coverage among 1-year-olds (%).39
# count                                          79.000000
# mean                                           82.518987
# std                                           218.314573
# min                                             2.000000
# 25%                                            33.500000
# 50%                                            62.000000
# 75%                                            86.500000
# max                                          1980.000000
#
# [8 rows x 40 columns]

# %% [markdown]
# - change format to:
#     - Country
#     - Year
#     - BCG immunization coverage among 1-year-olds

# %%
def wide_to_long(df, variable, value):
    new_header = df.iloc[0] #grab the first row for the header
    df = df[1:] #take the data less the header row
    df.columns = new_header #set the header row as the df header
    col_names = df.columns.values.tolist()
    return pd.melt(df, id_vars =col_names[0],value_vars = col_names[1:], var_name=variable, value_name=value)

# %%
bcg = wide_to_long(bcg_who,"Year", "BCG immunization coverage among 1-year-olds")
# Out:
#                                  Country  Year  \
# 0                            Afghanistan  2019
# 1                                Albania  2019
# 2                                Algeria  2019
# 3                                 Angola  2019
# 4                              Argentina  2019
# ...                                  ...   ...
# 6675  Venezuela (Bolivarian Republic of)  1980
# 6676                            Viet Nam  1980
# 6677                               Yemen  1980
# 6678                              Zambia  1980
# 6679                            Zimbabwe  1980
#
#       BCG immunization coverage among 1-year-olds
# 0                                            78.0
# 1                                            99.0
# 2                                            99.0
# 3                                            69.0
# 4                                            93.0
# ...                                           ...
# 6675                                         72.0
# 6676                                          NaN
# 6677                                          9.0
# 6678                                          NaN
# 6679                                          NaN
#
# [6680 rows x 3 columns]

# %% [markdown]
# ### Russian Data
#
# - find source asap and text rishi or make note of it

# %%
rus_rain.head()
# Out:
#    Rainfall - (MM)   Year    Statistics  Country  ISO3
# 0             21.1   1991   Jan Average   Russia   RUS
# 1             16.0   1991   Feb Average   Russia   RUS
# 2             16.4   1991   Mar Average   Russia   RUS
# 3             22.3   1991   Apr Average   Russia   RUS
# 4             34.3   1991   May Average   Russia   RUS

# %%
rus_temp.head()
# Out:
#    Temperature - (Celsius)   Year    Statistics  Country  ISO3
# 0                    -24.6   1991   Jan Average   Russia   RUS
# 1                    -24.8   1991   Feb Average   Russia   RUS
# 2                    -18.4   1991   Mar Average   Russia   RUS
# 3                     -5.0   1991   Apr Average   Russia   RUS
# 4                      3.9   1991   May Average   Russia   RUS

# %%
rus_rain.describe()
# Out:
#        Rainfall - (MM)         Year
# count       360.000000   360.000000
# mean         36.938333  2005.500000
# std          15.959272     8.667488
# min          11.500000  1991.000000
# 25%          22.675000  1998.000000
# 50%          33.550000  2005.500000
# 75%          50.150000  2013.000000
# max          70.200000  2020.000000

# %%
rus_temp.describe()
# Out:
#        Temperature - (Celsius)         Year
# count               360.000000   360.000000
# mean                 -5.159722  2005.500000
# std                  14.573464     8.667488
# min                 -29.700000  1991.000000
# 25%                 -19.300000  1998.000000
# 50%                  -4.450000  2005.500000
# 75%                   8.425000  2013.000000
# max                  16.100000  2020.000000

# %%
rus_data = pd.merge(rus_rain,rus_temp)

# %%
rus_data
# Out:
#      Rainfall - (MM)   Year    Statistics  Country  ISO3  \
# 0               21.1   1991   Jan Average   Russia   RUS
# 1               16.0   1991   Feb Average   Russia   RUS
# 2               16.4   1991   Mar Average   Russia   RUS
# 3               22.3   1991   Apr Average   Russia   RUS
# 4               34.3   1991   May Average   Russia   RUS
# ..               ...    ...           ...      ...   ...
# 355             55.9   2020   Aug Average   Russia   RUS
# 356             44.5   2020   Sep Average   Russia   RUS
# 357             39.7   2020   Oct Average   Russia   RUS
# 358             32.5   2020   Nov Average   Russia   RUS
# 359             22.1   2020   Dec Average   Russia   RUS
#
#      Temperature - (Celsius)
# 0                      -24.6
# 1                      -24.8
# 2                      -18.4
# 3                       -5.0
# 4                        3.9
# ..                       ...
# 355                     13.1
# 356                      7.9
# 357                     -2.3
# 358                    -11.8
# 359                    -23.0
#
# [360 rows x 6 columns]

# %%
rus_data.Statistics
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-d81e90e9fd5d> in <module>
# ----> 1 rus_data.Statistics
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Statistics'

# %%
month_name = "Jan"
datetime_object = datetime.datetime.strptime(month_name, "%b")
month_number = datetime_object.month
print(month_number)
# Out:
# 1

# %%
## we can take this oppurtunity to write code to replace instance of month name with a number
